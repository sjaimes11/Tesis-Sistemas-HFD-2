# %% [markdown]
# # SVM
#
# Notebook para entrenar y evaluar SVM lineal y RBF usando los CSV del servidor Linux.

# %%
from pathlib import Path
import os
import sys

def find_ml_classic_dir(script_name: str) -> Path:
    for base in [Path.cwd(), *Path.cwd().parents]:
        if (base / script_name).exists() and (base / "data_loader.py").exists():
            return base
        candidate = base / "ml_classic"
        if (candidate / script_name).exists() and (candidate / "data_loader.py").exists():
            return candidate
    raise FileNotFoundError("No se encontró la carpeta ml_classic")

ML_CLASSIC_DIR = find_ml_classic_dir("svm_model.py")
os.chdir(ML_CLASSIC_DIR)
if str(ML_CLASSIC_DIR) not in sys.path:
    sys.path.insert(0, str(ML_CLASSIC_DIR))

print(f"Usando ml_classic desde: {ML_CLASSIC_DIR}")
# Out:
# Usando ml_classic desde: /home/sajaimesp/Tesis_Sistemas/Data_Sets/ml_classic

# %%
from svm_model import train_svm

DATA_DIR = "/home/sajaimesp/Tesis_Sistemas/Data_Sets"
OUTPUT_DIR = "/home/sajaimesp/Tesis_Sistemas/ml_outputs"
BACKEND = "auto"
MAX_SAMPLES_PER_CLASS = 30000

DATA_DIR, OUTPUT_DIR, BACKEND, MAX_SAMPLES_PER_CLASS
# Out:
# ('/home/sajaimesp/Tesis_Sistemas/Data_Sets',
#  '/home/sajaimesp/Tesis_Sistemas/ml_outputs',
#  'auto',
#  30000)

# %%
model, scaler, results = train_svm(
    data_dir=DATA_DIR,
    output_dir=OUTPUT_DIR,
    backend=BACKEND,
    max_samples_per_class=MAX_SAMPLES_PER_CLASS,
)

results
# Out:
# Backend seleccionado para SVM: cpu (cuML/RAPIDS no está disponible; se usa scikit-learn en CPU.)
#
# Datasets cargados desde: /home/sajaimesp/Tesis_Sistemas/Data_Sets
# Dataset cargado: 72000 train, 18000 test
#   Clase 0 (            normal):   24000 train,   6000 test
#   Clase 1 (   mqtt_bruteforce):   24000 train,   6000 test
#   Clase 2 (            scan_A):   24000 train,   6000 test
#   Ratio desbalance (vs mayor): 1.0 / 1.0 / 1.0
#   -> Se recomienda class_weight='balanced' en todos los modelos
#
#
# ============================================================
#  Fase 1: Linear SVM (óptimo para ESP32)
# ============================================================
# Buscando mejores hiperparámetros para Linear SVM con scikit-learn...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sajaimesp/venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ============================================================
#  SVM (Linear)
# ============================================================
#  Mejores hiperparámetros: {'C': 10, 'class_weight': 'balanced', 'loss': 'hinge', 'max_iter': 5000}
#  CV F1 macro:   0.9015 ± 0.0016
#  Accuracy:      0.8993
#  F1 macro:      0.8980
#  F1 weighted:   0.8980
#  Precision:     0.9103
#  Recall:        0.8993
#  MCC:           0.8546
#
#  Classification Report:
#                  precision    recall  f1-score   support
#
#          normal     0.8145    0.9285    0.8678      6000
# mqtt_bruteforce     0.9178    0.9995    0.9569      6000
#          scan_A     0.9985    0.7698    0.8694      6000
#
#        accuracy                         0.8993     18000
#       macro avg     0.9103    0.8993    0.8980     18000
#    weighted avg     0.9103    0.8993    0.8980     18000
#
#  Confusion Matrix:
#                       normal bruteforce     scan_A
#            normal       5571        422          7
#   mqtt_bruteforce          3       5997          0
#            scan_A       1266        115       4619
#
#  Memoria ESP32 (Linear): ~168 bytes
#
# ============================================================
#  Fase 2: RBF SVM (mayor capacidad, más costoso en ESP32)
# ============================================================
# Buscando mejores hiperparámetros para RBF SVM con scikit-learn...
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
#
# ============================================================
#  SVM (RBF)
# ============================================================
#  Mejores hiperparámetros: {'C': 1, 'class_weight': 'balanced', 'gamma': 0.01}
#  CV F1 macro:   0.9017 ± 0.0016
#  Accuracy:      0.8998
#  F1 macro:      0.8986
#  F1 weighted:   0.8986
#  Precision:     0.9109
#  Recall:        0.8998
#  MCC:           0.8555
#
#  Classification Report:
#                  precision    recall  f1-score   support
#
#          normal     0.8149    0.9295    0.8684      6000
# mqtt_bruteforce     0.9181    0.9998    0.9572      6000
#          scan_A     0.9998    0.7702    0.8701      6000
#
#        accuracy                         0.8998     18000
#       macro avg     0.9109    0.8998    0.8986     18000
#    weighted avg     0.9109    0.8998    0.8986     18000
#
#  Confusion Matrix:
#                       normal bruteforce     scan_A
#            normal       5577        422          1
#   mqtt_bruteforce          1       5999          0
#            scan_A       1266        113       4621
#
#  Support Vectors: 15718
#  Memoria ESP32 (RBF): ~859.6 KB
#  WARNING: Demasiados SVs para ESP32. Considerar Linear SVM.
#
# ============================================================
#  Comparación Linear vs RBF
# ============================================================
#   Métrica             Linear        RBF
#   -----------------------------------
#   accuracy            0.8993     0.8998
#   f1_macro            0.8980     0.8986
#   f1_weighted         0.8980     0.8986
#   precision           0.9103     0.9109
#   recall              0.8993     0.8998
#   mcc                 0.8546     0.8555
#   memoria              168 B   880220 B
#
#  -> Recomendación: Linear SVM (rendimiento similar, mucho menor footprint)
#
# Modelos guardados (seleccionado: linear):
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/svm_best.pkl
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/svm_linear_best.pkl
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/svm_rbf_best.pkl
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/svm_selected.pkl
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/scaler_svm.pkl
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/feature_order.csv
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/label_map.json
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/scaler_params.json
# {'linear': (LinearSVC(C=10, class_weight='balanced', loss='hinge', max_iter=5000,
#             random_state=42),
#   {'accuracy': 0.8992777777777777,
#    'f1_macro': 0.8980170648045599,
#    'f1_weighted': 0.8980170648045601,
#    'precision': 0.9102583355320123,
#    'recall': 0.8992777777777778,
#    'mcc': np.float64(0.8546305989102998)},
#   168),
#  'rbf': (SVC(C=1, class_weight='balanced', gamma=0.01, random_state=42),
#   {'accuracy': 0.8998333333333334,
#    'f1_macro': 0.898579444628551,
#    'f1_weighted': 0.8985794446285509,
#    'precision': 0.9109261952909834,
#    'recall': 0.8998333333333334,
#    'mcc': np.float64(0.8555051557340773)},
#   880220)}
