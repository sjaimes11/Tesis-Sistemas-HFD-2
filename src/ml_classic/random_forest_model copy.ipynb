# %% [markdown]
# # Random Forest
#
# Notebook para entrenar y evaluar Random Forest usando los CSV del servidor Linux.

# %%
from pathlib import Path
import os
import sys

def find_ml_classic_dir(script_name: str) -> Path:
    for base in [Path.cwd(), *Path.cwd().parents]:
        if (base / script_name).exists() and (base / "data_loader.py").exists():
            return base
        candidate = base / "ml_classic"
        if (candidate / script_name).exists() and (candidate / "data_loader.py").exists():
            return candidate
    raise FileNotFoundError("No se encontró la carpeta ml_classic")

ML_CLASSIC_DIR = find_ml_classic_dir("random_forest_model.py")
os.chdir(ML_CLASSIC_DIR)
if str(ML_CLASSIC_DIR) not in sys.path:
    sys.path.insert(0, str(ML_CLASSIC_DIR))

print(f"Usando ml_classic desde: {ML_CLASSIC_DIR}")
# Out:
# Usando ml_classic desde: /home/sajaimesp/Tesis_Sistemas/Data_Sets/ml_classic

# %%
from random_forest_model import train_random_forest

DATA_DIR = "/home/sajaimesp/Tesis_Sistemas/Data_Sets"
OUTPUT_DIR = "/home/sajaimesp/Tesis_Sistemas/ml_outputs"
BACKEND = "auto"

DATA_DIR, OUTPUT_DIR, BACKEND
# Out:
# ('/home/sajaimesp/Tesis_Sistemas/Data_Sets',
#  '/home/sajaimesp/Tesis_Sistemas/ml_outputs',
#  'auto')

# %%
model, scaler, metrics = train_random_forest(
    data_dir=DATA_DIR,
    output_dir=OUTPUT_DIR,
    backend=BACKEND,
)

metrics
# Out:
# Backend seleccionado para Random Forest: cpu (cuML/RAPIDS no está disponible; se usa scikit-learn en CPU.)
#
# Datasets cargados desde: /home/sajaimesp/Tesis_Sistemas/Data_Sets
# Dataset cargado: 205018 train, 51255 test
#   Clase 0 (            normal):  137469 train,  34367 test
#   Clase 1 (   mqtt_bruteforce):   26463 train,   6616 test
#   Clase 2 (            scan_A):   41086 train,  10272 test
#   Ratio desbalance (vs mayor): 1.0 / 5.2 / 3.3
#   -> Se recomienda class_weight='balanced' en todos los modelos
#
# Buscando mejores hiperparámetros para Random Forest con scikit-learn (80 combinaciones)...
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# /home/sajaimesp/venv/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ============================================================
#  Random Forest
# ============================================================
#  Mejores hiperparámetros: {'n_estimators': 20, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'entropy', 'class_weight': None}
#  CV F1 macro:   0.9349 ± 0.0006
#  Accuracy:      0.9463
#  F1 macro:      0.9338
#  F1 weighted:   0.9445
#  Precision:     0.9716
#  Recall:        0.9058
#  MCC:           0.8913
#
#  Classification Report:
#                  precision    recall  f1-score   support
#
#          normal     0.9281    0.9973    0.9615     34367
# mqtt_bruteforce     0.9938    0.9406    0.9665      6616
#          scan_A     0.9929    0.7795    0.8734     10272
#
#        accuracy                         0.9463     51255
#       macro avg     0.9716    0.9058    0.9338     51255
#    weighted avg     0.9496    0.9463    0.9445     51255
#
#  Confusion Matrix:
#                       normal bruteforce     scan_A
#            normal      34275         35         57
#   mqtt_bruteforce        393       6223          0
#            scan_A       2261          4       8007
#
#
#  Feature Importance (top 5):
#          num_bytes: 0.2863
#       mean_pkt_len: 0.1501
#        max_pkt_len: 0.0998
#        min_pkt_len: 0.0889
#      num_psh_flags: 0.0819
#  Árboles: 20
#  Profundidad promedio: 20.0 (max 20)
#  Hojas promedio:       2052 (total 41036)
#
#  Estimación de memoria ESP32: ~1602.6 KB (82052 nodos)
#  ⚠ ADVERTENCIA: Modelo grande para ESP32 (>1603 KB).
#    Considerar reducir n_estimators o max_depth para deployment.
#
# Artefactos guardados:
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/random_forest_best.pkl
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/feature_order.csv
#   - /home/sajaimesp/Tesis_Sistemas/ml_outputs/label_map.json
# {'accuracy': 0.9463466978831333,
#  'f1_macro': 0.9337676026646071,
#  'f1_weighted': 0.9444657981715672,
#  'precision': 0.9716119558534132,
#  'recall': 0.9058064086264753,
#  'mcc': np.float64(0.8913182835701828)}
